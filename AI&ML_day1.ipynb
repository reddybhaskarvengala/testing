# %% [markdown]
# <a href="https://colab.research.google.com/github/reddybhaskarvengala/testing/blob/main/AI%26ML_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Analyzing time series using stats model

# %%
from random import random
time_series= [2 * x+ random() for x in range(1,100)]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot (time_series)
plt. show()

# %%
from statsmodels.tsa.ar_model import AutoReg

model = AutoReg(time_series , 2)
model_fit = model. fit()
y = model_fit.predict (len(time_series), len(time_series))
print (y)
# Out:
# [200.75755759]

# %%
model_fit.params
# Out:
# array([2.88233349, 0.56274232, 0.43724436])

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(time_series, order = (0, 1, 2))
model_fit = model.fit()
y = model_fit.predict(len(time_series), len(time_series))
print(y)
# Out:
# [199.28978229]

# %%
model_fit.params
# Out:
# array([0.9170705 , 0.51271438, 1.20861131])

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   99
# Model:                 ARIMA(0, 1, 2)   Log Likelihood                -148.875
# Date:                Mon, 15 Apr 2024   AIC                            303.749
# Time:                        09:38:18   BIC                            311.504
# Sample:                             0   HQIC                           306.886
#                                  - 99
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.9171      0.124      7.389      0.000       0.674       1.160
# ma.L2          0.5127      0.116      4.423      0.000       0.286       0.740
# sigma2         1.2086      0.234      5.175      0.000       0.751       1.666
# ...

# %%
import numpy as np
import pandas as pd

random_seed=np.random.RandomState(12)

# %%
X_train = 0.5 * random_seed.randn(500, 2)
X_train = np.r_[X_train + 3 , X_train]
X_train = pd.DataFrame(X_train, columns = ["x", "y"])
X_train.head()
# Out:
#           x         y
# 0  3.236493  2.659287
# 1  3.121220  2.149632
# 2  3.376571  2.232639
# 3  3.002564  2.939886
# 4  2.596509  4.435910

# %%
X_test = 0.5 * random_seed.randn(500, 2)

X_test = np.r_[X_test + 3 , X_test]


X_test = pd.DataFrame(X_test, columns = ["x", "y"])


X_test.head()
# Out:
#           x         y
# 0  3.944575  3.866919
# 1  2.984853  3.142150
# 2  3.501735  2.168262
# 3  2.906300  3.233826
# 4  3.273225  3.261790

# %%
X_outliers = random_seed.uniform(low=-5, high=5, size=(50,2))

X_outliers = pd.DataFrame(X_outliers, columns=["x", "y"])

X_outliers.head()
# Out:
#           x         y
# 0  3.947504  2.891003
# 1  0.413976 -2.025841
# 2 -2.644476 -3.480783
# 3 -0.518212 -3.386443
# 4  2.977669  2.215355

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

p1 = plt.scatter(X_train.x, X_train.y, c = "red", s= 50, edgecolor="black")
p2 = plt.scatter(X_test.x, X_test.y, c = "green", s= 50, edgecolor="black")
p3 = plt.scatter(X_outliers.x, X_outliers.y, c = "blue", s= 50, edgecolor="black")


plt.xlim((-6, 6))
plt.ylim((-6, 6))

plt.legend([p1, p2, p3],
      ["training set", "normal testing set", "anomalous testing set"],
      loc = "lower right",)

plt.show()

# %%
from sklearn.ensemble import IsolationForest

clf = IsolationForest()

clf.fit(X_train)

y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)
y_pred_outliers = clf.predict(X_outliers)

X_outliers = X_outliers.assign(pred = y_pred_outliers)
X_outliers.head()
# Out:
#           x         y  pred
# 0  3.947504  2.891003    -1
# 1  0.413976 -2.025841    -1
# 2 -2.644476 -3.480783    -1
# 3 -0.518212 -3.386443    -1
# 4  2.977669  2.215355     1

# %%
p1 = plt.scatter(X_train.x, X_train.y, c = "red", s= 50, edgecolor="black")

p2 = plt.scatter( X_outliers.loc[X_outliers.pred == -1, ["x"]],
                  X_outliers.loc[X_outliers.pred == -1, ["y"]],
                  c = "blue", s= 50, edgecolor="black")

p3 = plt.scatter( X_outliers.loc[X_outliers.pred == 1, ["x"]],
                  X_outliers.loc[X_outliers.pred == 1, ["y"]],
                  c = "green", s= 50, edgecolor="black")

plt.xlim((-6, 6))
plt.ylim((-6, 6))

plt.legend([p1, p2, p3],
      ["training Observations ", "detected outliers", "incorrectly labeled outliers"],
      loc = "lower right",)

plt.show()

# %%
import pandas as pd
data=pd.read_csv("file_pe_headers.csv", sep=",")
data.head()
# Out:
#                                           Name  e_magic  e_cblp  e_cp  e_crlc  \
# 0  VirusShare_a878ba26000edaac5c98eff4432723b3    23117     144     3       0
# 1  VirusShare_ef9130570fddc174b312b2047f5f4cf0    23117     144     3       0
# 2  VirusShare_ef84cdeba22be72a69b198213dada81a    23117     144     3       0
# 3  VirusShare_6bf3608e60ebc16cbcff6ed5467d469e    23117     144     3       0
# 4  VirusShare_2cc94d952b2efb13c7d6bbe0dd59d3fb    23117     144     3       0
#
#    e_cparhdr  e_minalloc  e_maxalloc  e_ss  e_sp  ...  SectionMaxChar  \
# 0          4           0       65535     0   184  ...      3758096608
# 1          4           0       65535     0   184  ...      3791650880
# 2          4           0       65535     0   184  ...      3221225536
# 3          4           0       65535     0   184  ...      3224371328
# 4          4           0       65535     0   184  ...      3227516992
#
#    SectionMainChar  DirectoryEntryImport  DirectoryEntryImportSize  \
# ...

# %%
X=data.drop(["Name","Malware"],axis=1).to_numpy()
print(X)
# Out:
# [[2.31170e+04 1.44000e+02 3.00000e+00 ... 7.78240e+04 7.37280e+04
#   0.00000e+00]
#  [2.31170e+04 1.44000e+02 3.00000e+00 ... 2.94912e+05 0.00000e+00
#   3.46112e+05]
#  [2.31170e+04 1.44000e+02 3.00000e+00 ... 4.09600e+04 0.00000e+00
#   0.00000e+00]
#  ...
#  [2.31170e+04 0.00000e+00 0.00000e+00 ... 6.14400e+04 0.00000e+00
#   0.00000e+00]
#  [2.31170e+04 1.44000e+02 3.00000e+00 ... 1.02400e+05 0.00000e+00
#   0.00000e+00]
#  [2.31170e+04 1.44000e+02 3.00000e+00 ... 5.57056e+05 0.00000e+00
#   0.00000e+00]]

# %%
from sklearn.preprocessing import StandardScaler
x_standardized=StandardScaler().fit_transform(X)
print(x_standardized)
# Out:
# [[ 0.         -0.03506542 -0.04751096 ... -0.07054894 -0.0198525
#   -0.04066791]
#  [ 0.         -0.03506542 -0.04751096 ... -0.03849221 -0.02110877
#   -0.02469983]
#  [ 0.         -0.03506542 -0.04751096 ... -0.07599254 -0.02110877
#   -0.04066791]
#  ...
#  [ 0.         -0.18093613 -0.04958686 ... -0.07296832 -0.02110877
#   -0.04066791]
#  [ 0.         -0.03506542 -0.04751096 ... -0.06691988 -0.02110877
#   -0.04066791]
#  [ 0.         -0.03506542 -0.04751096 ...  0.00021781 -0.02110877
#   -0.04066791]]

# %% [markdown]
# axis=1 is drop the column.
# How to delete some rows?
# X=data.drop([1,2,3],axis=0)

# %%
data.shape
# Out:
# (19611, 79)

# %%
data.describe()
# Out:
#        e_magic        e_cblp          e_cp        e_crlc     e_cparhdr  \
# count  19611.0  19611.000000  19611.000000  19611.000000  19611.000000
# mean   23117.0    178.615726     71.660752     49.146958     37.370710
# std        0.0    987.200729   1445.192977   1212.201919    864.515405
# min    23117.0      0.000000      0.000000      0.000000      0.000000
# 25%    23117.0    144.000000      3.000000      0.000000      4.000000
# 50%    23117.0    144.000000      3.000000      0.000000      4.000000
# 75%    23117.0    144.000000      3.000000      0.000000      4.000000
# max    23117.0  59448.000000  63200.000000  64613.000000  43690.000000
#
#          e_minalloc    e_maxalloc          e_ss         e_sp        e_csum  \
# count  19611.000000  19611.000000  19611.000000  19611.00000  19611.000000
# mean      37.032635  64178.739687     10.418490    226.46530     29.689103
# std      915.833139   9110.755873    637.116265   1249.68033   1015.303419
# ...

# %% [markdown]
# #Training an XGBoost Classifier

# %%
import pandas as pd

df = pd.read_csv("file_pe_headers.csv", sep=",")

df.head()
# Out:
#                                           Name  e_magic  e_cblp  e_cp  e_crlc  \
# 0  VirusShare_a878ba26000edaac5c98eff4432723b3    23117     144     3       0
# 1  VirusShare_ef9130570fddc174b312b2047f5f4cf0    23117     144     3       0
# 2  VirusShare_ef84cdeba22be72a69b198213dada81a    23117     144     3       0
# 3  VirusShare_6bf3608e60ebc16cbcff6ed5467d469e    23117     144     3       0
# 4  VirusShare_2cc94d952b2efb13c7d6bbe0dd59d3fb    23117     144     3       0
#
#    e_cparhdr  e_minalloc  e_maxalloc  e_ss  e_sp  ...  SectionMaxChar  \
# 0          4           0       65535     0   184  ...      3758096608
# 1          4           0       65535     0   184  ...      3791650880
# 2          4           0       65535     0   184  ...      3221225536
# 3          4           0       65535     0   184  ...      3224371328
# 4          4           0       65535     0   184  ...      3227516992
#
#    SectionMainChar  DirectoryEntryImport  DirectoryEntryImportSize  \
# ...

# %%
y = df["Malware"]
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 19606    0
# 19607    0
# 19608    0
# 19609    0
# 19610    0
# Name: Malware, Length: 19611, dtype: int64

# %%
X = df.drop(["Name", "Malware"], axis = 1).to_numpy()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from xgboost import XGBClassifier

XGB_model_instance = XGBClassifier()

XGB_model_instance.fit(X_train, y_train)

y_test_pred = XGB_model_instance.predict(X_test)

y_test_pred
# Out:
# array([1, 1, 0, ..., 0, 1, 1])

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_test_pred)

print("Accuracy : %.2f%%" % (accuracy * 100))
# Out:
# Accuracy : 99.47%
